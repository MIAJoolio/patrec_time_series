# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os


url = "https://timeseriesclassification.com/dataset.php"
response = requests.get(url)
print(f'response: {response}')

soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# response: <Response [200]>
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/html">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <title>Time Series Classification Website</title>
# <!-- Bootstrap -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/mystyle.css" rel="stylesheet"/>
# <link href="css/page_css/dataset.css" rel="stylesheet"/>
# <!-- Latest compiled and minified CSS -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-table/1.11.0/bootstrap-table.css" rel="stylesheet"/>
# <link href="http://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet" type="text/css"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# ...

# %%
from aeon.datasets import load_classification

X, y = load_classification('AsphaltRegularityCoordinates') # AsphaltPavementTypeCoordinates

# %%
len(X), X[0].shape
# Out:
# (1502, (3, 367))

# %%
[1,2,3,4,5][:3], [1,2,3,4,5][3:]
# Out:
# ([1, 2, 3], [4, 5])

# %%
# dimensions_num - classes num 
## TRAFFIC ## 
# Chinatown (1-2) # MelbournePedestrian (1-10)
## SPECTRO ##
# EthanolConcentration (3-4) # EthanolLevel (1-2) # Rock (1-4) # Ham (1-2)
## SIMULATED ## (?)
# ShapeletSim (1-2) Mallat (1-8)
## SENSOR ##
# ItalyPowerDemand (1-1) # ElectricDeviceDetection (1-2) # Earthquakes (1-2) # Car (1-4) # FaultDetectionA (1-3) # DodgerLoopDay (1-3) # BasicMotions (4-6)
## OTHER ## 
# ECG200 (1-2) # ECG5000 (1-5) # DucksAndGeese (1-5)

# %%
from typing import Any, Tuple
import os
from pathlib import Path
os.chdir('/root/autolabeling_time_series_data/')

import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

dataset_name = 'DucksAndGeese' # 'ECG5000' # 'ECG200' #'BasicMotions' # 'DodgerLoopDay' #'FaultDetectionA' #'Car' # 'Earthquakes' # 'ElectricDeviceDetection' #'ItalyPowerDemand' #'Mallat' #'ShapeletSim' #'Ham' #'Rock' # 'EthanolLevel' #'EthanolConcentration' #'MelbournePedestrian' #'Chinatown'

dir_path = Path('data/UCR_benchmark/datasets')
dt_path = dir_path / dataset_name

# TODO для неравных по длине датасетов

if not dt_path.is_dir():
    raise ValueError("Incorrect dataset name! Not in UCR benchmark!")

X, y = np.load(dt_path/'raw_features.npy'), pd.read_csv(dt_path/'labels.csv', header=None).values

X.shape, y.shape
# Out:
# ((100, 1, 236784), (100, 1))

# %%
# import matplotlib.pyplot as plt
# for k in range(25):
#     plt.figure()
#     print(y[k])
#     pd.Series(X[k].reshape(-1,)).plot()

# %%
np.array(['category', 'category']).dtype
# Out:
# dtype('<U8')
